# %% [markdown]
# # Biology Explanations Generator
#
# Generate pedagogically rigorous explanations for Biology questions B11-B160 following the specified framework:
# - 6-8 sentences minimum per explanation
# - Mechanism/concept explanation (3-4 sentences)
# - Real-world application/significance (1-2 sentences)
# - Detailed scientific refutation for EACH wrong option (1-2 sentences each)

# %%
import json
import re

# Read the questions.js file
questions_file_path = r'c:\Users\user\Desktop\PrePa\questions.js'

with open(questions_file_path, 'r', encoding='utf-8') as f:
    content = f.read()

# Extract only the Biology section
biology_start = content.find('"Biology": [')
biology_end = content.find('  ],\n  "CRS":', biology_start)
biology_section = content[biology_start:biology_end+5]

# Extract the JSON array
questions_start = biology_section.find('[')
questions_end = biology_section.rfind(']')
questions_json_str = biology_section[questions_start:questions_end+1]

# Parse
biology_questions = json.loads(questions_json_str)
print(f"Total Biology questions: {len(biology_questions)}")
print(f"IDs range: {biology_questions[0]['id']} to {biology_questions[-1]['id']}")

# Filter B11-B160
b11_160 = [q for q in biology_questions if int(q['id'][1:]) >= 11 and int(q['id'][1:]) <= 160]
print(f"Filtered B11-B160: {len(b11_160)} questions")

# %%
# Comprehensive pedagogical explanations for all B11-B160
# Organized by biological topic for consistency and depth

explanations = {
    "B11": "Why \"Photosynthesis\" is correct:\n- Photosynthesis is the fundamental biochemical process by which autotrophic organisms (primarily green plants) harness light energy from the sun to convert carbon dioxide and water into glucose and oxygen. During light reactions in thylakoid membranes, chlorophyll absorbs photons and splits water molecules, releasing oxygen and generating ATP and NADPH. The light-independent reactions (Calvin cycle) in the stroma then use this ATP and NADPH to fix CO2 into glucose. This process is of supreme biological importance as it forms the base of virtually all food chains, being the primary source of organic molecules and oxygen for all life.\nWhy the other options are not correct:\n- \"Respiration\" is incorrect because it is the reverse process where glucose is oxidized to release energy; respiration consumes oxygen and produces CO2 rather than fixing CO2 into food.\n- \"Transpiration\" is incorrect because it is purely the physical evaporation of water through stomata in leaves, serving water uptake and temperature regulation, not food synthesis.\n- \"Digestion\" is incorrect because it is the breakdown of existing food molecules into smaller fragments for absorption, not the manufacture of new food from inorganic materials.",
    
    "B12": "Why \"Nitrogen\" is correct:\n- Macronutrients are mineral elements required in large quantities (grams per organism), and nitrogen is one of the most essential. Nitrogen is the backbone of amino acids making up proteins, and it is part of nucleotides forming DNA and RNA. Plants obtain nitrogen from soil as nitrates or ammonium ions, often with help from nitrogen-fixing bacteria that convert atmospheric N2, while animals obtain nitrogen from protein-rich foods. The global nitrogen cycle involving fixation, nitrification, denitrification, and ammonification demonstrates nitrogen's critical role in supporting all life on Earth.\nWhy the other options are not correct:\n- \"Iron\" is incorrect because while essential (in hemoglobin for oxygen transport), it is needed only in small quantities (milligrams) and is classified as a micronutrient, not a macronutrient.\n- \"Zinc\" is incorrect because though vital for immunity and enzyme function, it is required only in micrograms, making it a micronutrient distinct from macronutrients needed in large amounts.\n- \"Copper\" is incorrect because copper is a micronutrient involved in electron transport and hemoglobin synthesis, but needed only in trace amounts unlike macronutrients.",
    
    "B13": "Why \"Scurvy\" is correct:\n- Scurvy is a disease caused by vitamin C deficiency, a water-soluble vitamin the human body cannot synthesize. Vitamin C acts as a critical cofactor in hydroxylation reactions, enabling the biochemical cross-linking that stabilizes collagen molecules. Collagen provides structural integrity to connective tissues, blood vessels, bones, gums, and skin; without proper collagen, these tissues weaken and break down. Symptoms include bleeding gums, poor wound healing, joint pain from fragile connective tissue, and eventual death if severe. Historically common among sailors on long voyages lacking fresh fruits and vegetables, scurvy demonstrates how a single missing micronutrient can cause systemic physiological failure.\nWhy the other options are not correct:\n- \"Rickets\" is incorrect because rickets results from vitamin D deficiency, causing improper bone mineralization and skeletal deformities, not collagen breakdown.\n- \"Beriberi\" is incorrect because beriberi results from thiamine (vitamin B1) deficiency, affecting nervous and cardiovascular systems with nerve damage and heart dysfunction.\n- \"Night blindness\" is incorrect because it results from vitamin A deficiency affecting retinoid synthesis for visual pigments, not from vitamin C deficiency.",
    
    "B14": "Why \"Pepsin\" is correct:\n- Pepsin is a protease enzyme secreted by gastric chief cells that specifically cleaves peptide bonds in protein molecules, breaking large proteins into smaller polypeptide fragments. It functions optimally in the highly acidic stomach environment (pH 1.5-3.5) where HCl provides both the precursor pepsinogen's activation and optimal pH for catalysis. This initial proteolysis in the stomach is crucial for protein digestion because it exposes proteins to further enzymatic processing, ensuring complete amino acid liberation for absorption. The sequential action of pepsin in the stomach followed by trypsin in the small intestine enables complete protein digestion and nutrient absorption essential for tissue growth and maintenance.\nWhy the other options are not correct:\n- \"Amylase\" is incorrect because amylase is a carbohydrate-digesting enzyme found in saliva and pancreatic secretions that breaks starch into sugars, not involved in protein digestion.\n- \"Lipase\" is incorrect because lipase hydrolyzes triglycerides into fatty acids and glycerol; although some gastric lipase exists, the primary lipid digestion site is the small intestine, not the stomach.\n- \"Trypsin\" is incorrect because trypsin is a pancreatic serine protease secreted into the small intestine, not the stomach, and acts after pepsin to complete protein digestion.",
    
    "B15": "Why \"Liver\" is correct:\n- The liver synthesizes bile, a complex fluid containing bile salts, cholesterol, phospholipids, and bilirubin essential for fat digestion and absorption. Hepatocytes continuously produce bile via cholesterol metabolism, which is stored in the gallbladder and released upon cholecystokinin stimulation by dietary fat in the small intestine. Bile salts function biochemically as biological detergents, emulsifying lipid droplets into much smaller micelles that dramatically increase lipid surface area for pancreatic lipase action. The liver also uses bile to eliminate excess cholesterol and bilirubin (hemoglobin breakdown product), making it essential for both nutrient processing and bodily waste elimination.\nWhy the other options are not correct:\n- \"Stomach\" is incorrect because the stomach produces gastric juice containing HCl and pepsinogen for protein digestion, not bile for lipid digestion.\n- \"Pancreas\" is incorrect because the pancreas produces digestive enzymes (amylase, lipase, proteases) and hormones like insulin, not bile.\n- \"Gall bladder\" is incorrect because while the gallbladder stores and concentrates bile, it does not produce bile; the liver is the producing organ.",
    
    "B16": "Why \"Glucose\" is correct:\n- Glucose is the monosaccharide end product of carbohydrate digestion, representing the simplest form into which complex starches must be broken. Carbohydrate digestion begins in the mouth with salivary amylase and continues in the small intestine with pancreatic amylase, which breaks polysaccharides into maltose molecules. Intestinal brush border enzymes (maltase, isomaltase, sucrase) further hydrolyze these disaccharides into glucose monomers that can be absorbed through the intestinal epithelium via active transport. Glucose is then transported directly to cells throughout the body where it enters glycolysis and cellular respiration, serving as the primary energy substrate for virtually all cells.\nWhy the other options are not correct:\n- \"Amino acids\" is incorrect because amino acids are the end products of protein digestion, not carbohydrate digestion.\n- \"Fatty acids\" is incorrect because fatty acids are products of lipid digestion, resulting from triglyceride hydrolysis by lipase, not from carbohydrate breakdown.\n- \"Glycerol\" is incorrect because glycerol is the other product of lipid digestion (from triglycerides), not a product of carbohydrate digestion.",
    
    "B17": "Why \"Carrots\" is correct:\n- Carrots are an excellent biological source of beta-carotene, a fat-soluble carotenoid pigment that the body (primarily the liver) converts into vitamin A (retinol) through enzymatic cleavage and oxidation. Vitamin A serves as the prosthetic group for opsin protein in retinal photoreceptors, forming rhodopsin which captures photons during vision initiation. Additionally, vitamin A is essential for epithelial cell differentiation and immune function, and its deficiency leads to night blindness and immune compromise. The orange color in carrots specifically derives from high beta-carotene concentration, making them botanically recognizable as a vitamin A source.\nWhy the other options are not correct:\n- \"Citrus fruits\" is incorrect because citrus fruits are excellent sources of vitamin C (ascorbic acid), not vitamin A.\n- \"Rice\" is incorrect because rice is primarily a carbohydrate source; while some white rice is fortified with vitamins synthetically, it is not a natural dietary source of vitamin A.\n- \"Meat\" is incorrect because although meat contains some retinol (animal vitamin A form), it contains far less than vegetable carotenoid sources like carrots.",
    
    "B18": "Why \"Villi\" is correct:\n- Villi are microscopic, finger-like projections of the small intestine mucosa that dramatically increase the absorptive surface area by approximately 30-fold. Each villus contains a capillary network for nutrient absorption and a central lacteal (lymphatic vessel) for absorbing lipids, surrounded by specialized epithelial cells with microvilli that provide an additional surface area increase of 200-fold. This extraordinary surface amplification is crucial because it allows rapid absorption of digestion products (monosaccharides, amino acids, lipids, minerals, vitamins) at rates sufficient to meet nutritional demands. The mucosal epithelium is only 1-2 cells thick, enabling passive and active transport of nutrients from the lumen into bloods at peak efficiency.\nWhy the other options are not correct:\n- \"Cilia\" is incorrect because cilia are hair-like organelles used for cellular movement or fluid propulsion (as in respiratory tract mucosa), not for nutrient absorption in the intestine.\n- \"Flagella\" is incorrect because flagella are long whip-like structures used for cell locomotion in microorganisms, not present in mammalian intestinal tissues.\n- \"Tentacles\" is incorrect because tentacles are predatory appendages found in certain aquatic organisms, not structures present in mammalian intestinal anatomy.",
    
    "B19": "Why \"Autotrophic\" is correct:\n- Autotrophic organisms are those that synthesize their own organic compounds from inorganic materials using energy (either light or chemical), serving as primary producers in ecosystems. Heterotrophic nutrition, by contrast, includes all organisms that must obtain organic compounds by consuming other organisms or their products. Parasitic nutrition involves feeding on a living host organism to the host's detriment; saprophytic nutrition involves decomposing dead organic matter; holozoic nutrition involves ingesting other organisms or food particles. These three types—parasitic, saprophytic, and holozoic—are all forms of heterotrophic nutrition.\nWhy the other options are not correct:\n- \"Parasitic\" is incorrect because parasitic nutrition is a type of heterotrophic nutrition where organisms live on/in hosts, not the opposite of heterotrophy.\n- \"Saprophytic\" is incorrect because saprophytic organisms feed on dead matter, representing a type of heterotrophic nutrition practiced by decomposers.\n- \"Holozoic\" is incorrect because holozoic nutrition (ingestion of food particles or organisms) is a fundamental type of heterotrophic nutrition found in animals.",
    
    "B20": "Why \"Starch\" is correct:\n- Starch is a polysaccharide storage carbohydrate synthesized by plants consisting of two glucose polymers called amylose (linear) and amylopectin (branched). Plants photosynthesize glucose during the day and polymerize it into starch granules in plastids for storage, allowing the plant to access glucose energy during night-time respiration and during periods when photosynthesis cannot occur. When plants require immediate energy, amylase enzymes hydrolyze starch back into glucose molecules that enter glycolysis and cellular respiration. Starch serves as the primary carbohydrate storage form in plants, accumulating in seeds, roots, and tubers.\nWhy the other options are not correct:\n- \"Glycogen\" is incorrect because glycogen is the animal storage polysaccharide, not the plant polysaccharide; animals synthesize and store glycogen in liver and muscle tissue.\n- \"Glucose\" is incorrect because glucose is a monosaccharide monomer used immediately for energy, not a storage polymer; glucose is too soluble to accumulate to storage concentrations without osmotic problems.\n- \"Cellulose\" is incorrect because cellulose is a structural polysaccharide forming plant cell walls, not a storage polysaccharide; it is not enzymatically degraded for plant energy."
}

print(f"Created explanations dictionary with {len(explanations)} entries")
print("Sample explanation for B11 (length):", len(explanations['B11']), "characters")

# %%
# Add explanations B21-B50
explanations.update({
    "B21": "Why \"Plasma\" is correct:\n- Plasma is the liquid matrix of blood consisting of water, proteins (albumin, globulins, fibrinogen), salts, and dissolved gases that suspends and transports blood cells throughout the cardiovascular system. Plasma comprises approximately 55% of total blood volume and serves as the solvent medium in which erythrocytes, leukocytes, and thrombocytes are suspended. This fluid medium transports nutrients from the digestive system, oxygen and CO2 from respiratory surfaces, hormones, antibodies, clotting factors, and metabolic wastes throughout the body. The osmotic pressure maintained by plasma proteins (especially albumin) is critical for blood pressure regulation and fluid compartmentalization between blood and tissue spaces.\nWhy the other options are not correct:\n- \"Serum\" is incorrect because serum is plasma without fibrinogen (the clotting protein), obtained only after blood coagulation; serum is a laboratory preparation, not a component of circulating blood.\n- \"Platelets\" is incorrect because platelets are cellular fragments involved in hemostasis and clotting, not the liquid portion of blood.\n- \"Haemoglobin\" is incorrect because hemoglobin is an iron-containing protein inside red blood cells for oxygen transport, not the liquid plasma component.",
    
    "B22": "Why \"Red blood cell\" is correct:\n- Red blood cells (erythrocytes) are specialized cells that transport oxygen from lungs to tissues through their hemoglobin protein content, which binds oxygen reversibly with high affinity at low partial pressures (lungs) and releases it at high partial pressures (tissues). Mature mammalian red blood cells lack nuclei and organelles, allowing maximum cytoplasmic space for hemoglobin; each red cell contains ~280 million hemoglobin molecules. The iron-containing heme prosthetic groups in hemoglobin (4 per hemoglobin tetramer) allow binding of 4 oxygen molecules with cooperative binding kinetics that enhance oxygen pickup and release. Red cells are continuously produced in bone marrow from hematopoietic stem cells and circulate for 120 days before removal by the spleen.\nWhy the other options are not correct:\n- \"White blood cell\" is incorrect because white blood cells provide immune defense against pathogens and are involved in inflammation and tissue repair, not oxygen transport.\n- \"Platelets\" is incorrect because platelets are involved in hemostasis and blood clotting through adhesion and aggregation, not oxygen transport.\n- \"Lymphocyte\" is incorrect because lymphocytes are a type of white blood cell involved in immunity (B cells, T cells, NK cells), not oxygen transport.",
    
    "B23": "Why \"Group O\" is correct:\n- Group O blood lacks both A and B antigens on erythrocyte surfaces (genotype: ii), making red cells from group O donors compatible with recipients of all blood groups because no ABO antigen-antibody incompatibility reactions occur. However, group O individuals have both anti-A and anti-B antibodies naturally present in their plasma, making them universal donors for red cells but not for plasma. Approximately 41% of humans globally are group O, the most common ABO phenotype. Group O blood's universal donor status for cells makes it extremely valuable in emergency transfusions when recipient blood type is unknown.\nWhy the other options are not correct:\n- \"Group A\" is incorrect because group A RBCs have A antigens that trigger agglutination in recipients with anti-A antibodies (groups B and O), preventing donation to those groups.\n- \"Group B\" is incorrect because group B RBCs have B antigens that trigger agglutination in recipients with anti-B antibodies (groups A and O), preventing donation to all but AB recipients.\n- \"Group AB\" is incorrect because group AB individuals have anti-O characteristics making group O incompatible; conversely, AB is the universal recipient, not donor type.",
    
    "B24": "Why \"Xylem\" is correct:\n- Xylem is a complex vascular tissue in plants composed of tracheary elements (tracheids and vessel elements), fibers, and parenchyma cells that transports water and mineral nutrients from roots upward through the plant body. Tracheary elements are dead at maturity but possess reinforced cell walls and pit structures that allow water transport through capillary action and root pressure without metabolic cost. This transport mechanism, called xylem sap flow, moves water against gravity from roots to leaves sometimes reaching heights over 100 meters in tall trees, defying gravitational pull through cohesion-tension mechanisms. The xylem is derived from the procambium during primary growth and from vascular cambium during secondary growth, continuously accommodating increases in plant girth.\nWhy the other options are not correct:\n- \"Phloem\" is incorrect because phloem transports manufactured sugars and organic compounds downward from leaves to sink tissues, not water and minerals upward.\n- \"Cambium\" is incorrect because cambium is a meristematic tissue that produces new xylem and phloem cells through cell division, not involved in transport.\n- \"Cortex\" is incorrect because cortex is a tissue region storing nutrients and water, not the primary transport tissue for water and mineral uptake.",
    
    "B25": "Why \"Phloem\" is correct:\n- Phloem is a living vascular tissue composed of sieve tube elements with companion cells, fibers, and parenchyma that transports organic compounds (primarily photosynthetic products like sucrose) from leaf photosynthetic tissues to sink tissues requiring carbohydrates. Sieve tube elements are living cells connected by sieve plates with plasmodesmata, allowing protoplasmic continuity for active transport of sugars using companion cells' ATP energy. This transport mechanism, called translocation, moves sugars in both acropetal (upward) and basipetal (downward) directions depending on sink positions. Unlike xylem which relies on passive water movement, phloem transports require living cells and continuous metabolic energy to maintain the osmotic gradients driving sugar flow.\nWhy the other options are not correct:\n- \"Xylem\" is incorrect because xylem transports water and mineral nutrients upward from roots, not manufactured food and organic compounds through living tissues.\n- \"Pith\" is incorrect because pith is parenchymatous tissue in stem centers that stores nutrients but does not function as a transport tissue.\n- \"Epidermis\" is incorrect because epidermis is a protective cellular layer forming the plant surface, not a conducting tissue for organic compound transport.",
    
    "B26": "Why \"Heart\" is correct:\n- The heart is a muscular four-chambered organ that functions mechanically as a double pump, with the right side receiving deoxygenated blood from tissues and pumping it to lungs, while the left side receives oxygenated blood from lungs and pumps it throughout the body. Cardiac myocyte contractions are coordinated by intrinsic electrical conduction systems initiating from the sinoatrial node (natural pacemaker) and propagating through the atria and ventricles via specialized conduction pathways. The rhythmic contraction and relaxation cycle (cardiac cycle) creates the alternating pressure changes that open and close valves but propel blood through systemic and pulmonary circulation. Approximately 70 contractions per minute at rest pump ~5 liters of blood continuously throughout a person's lifetime.\nWhy the other options are not correct:\n- \"Lungs\" is incorrect because lungs function in gas exchange (extracting oxygen and removing CO2 from blood), not in actively pumping blood through circulation.\n- \"Brain\" is incorrect because the brain is the command center controlling heart rate through autonomic nervous system signals, not the organ that physically pumps blood.\n- \"Kidney\" is incorrect because kidneys filter blood to form urine and regulate blood composition, not actively pump blood through the body.",
    
    "B27": "Why \"Artery\" is correct:\n- Arteries are blood vessels that transport blood away from the heart under high pressure, carrying oxygenated blood (except for pulmonary arteries carrying deoxygenated blood to lungs). Arterial walls are highly muscular and elastic with thick tunica media layers containing smooth muscle cells and elastic fibers that withstand high pressures and help propel blood through elastic recoil. This wall composition allows arteries to withstand systolic pressures reaching 120 mmHg in healthy individuals and to contribute to diastolic blood pressure maintenance through elastic rebound. Large elastic arteries branch progressively into smaller muscular arteries then into arterioles that provide peripheral resistance regulation via sympathetic smooth muscle innervation.\nWhy the other options are not correct:\n- \"Vein\" is incorrect because veins carry blood toward the heart from tissues under low pressure, typically carrying deoxygenated blood; veins have thin, less muscular walls adapted for low-pressure flow.\n- \"Capillary\" is incorrect because capillaries are tiny vessels only 5-10 micrometers in diameter composed of a single endothelial cell layer; they function in gas and nutrient exchange, not in conducting high-pressure flow away from the heart.\n- \"Venule\" is incorrect because venules are small vessels receiving blood from capillaries and draining into larger veins; they carry blood toward the heart, not away from it.",
    
    "B28": "Why \"Vein\" is correct:\n- Veins possess one-way valves in their lumens consisting of endothelial finger-like projections that allow blood flow toward the heart but prevent backflow away from the heart when venous pressure drops. These valves are particularly abundant in leg veins working against gravity to return blood from distal tissues toward the heart against gravitational resistance. Venous valve incompetence leads to venous reflux, distension, and varicose vein formation, impaired blood return, and potential thrombosis. This unidirectional valve arrangement functionally transforms veins into one-way conduits ensuring continuous net blood movement toward the right atrium despite low venous pressure fluctuations.\nWhy the other options are not correct:\n- \"Artery\" is incorrect because arteries lack valves and rely on high pressure from heart contractions to propel blood forward continuously; even if arterial backflow occurred briefly, arteries don't anatomically possess valve structures.\n- \"Capillary\" is incorrect because capillaries are microscopic vessels through which fluid and solutes exchange freely through endothelial gaps; being single-cell layers, they lack valves or distinct lumen architecture.\n- \"Arteriole\" is incorrect because arterioles are small resistance vessels connecting arteries to capillaries; they lack valves and their smooth muscle cells remain innervated by sympathetic nerves for vasoconstriction/dilation.",
    
    "B29": "Why \"Haemoglobin\" is correct:\n- Hemoglobin is an iron-containing metalloprotein tetramer (four polypeptide chains: 2 alpha, 2 beta) with four heme prosthetic groups (iron+porphyrin), each capable of reversibly binding one oxygen molecule, allowing each hemoglobin to transport four O2 molecules. The iron atom in each heme group exists in the +2 (ferrous) oxidation state and resides at the hydrophobic core of the globin fold, allowing stabilized oxygen coordination without oxidation to +3 state. This reversible binding property is critical for oxygen loading in lungs (high pO2) and unloading in tissues (low pO2), with cooperativity mechanisms enhancing oxygen pickup and release kinetics. The iron content gives hemoglobin and whole blood its red color; non-iron proteins like myoglobin cannot produce blood's characteristic coloration.\nWhy the other options are not correct:\n- \"Melanin\" is incorrect because melanin is a non-iron organic polymer pigment responsible for skin and hair coloration in animals, not involved in oxygen transport.\n- \"Chlorophyll\" is incorrect because chlorophyll is a magnesium-containing pigment in plants involved in light absorption for photosynthesis, not present in animal blood.\n- \"Xanthophyll\" is incorrect because xanthophyll is a yellow-orange carotenoid plant pigment involved in photosynthesis light harvesting, not present in animal tissues.",
    
    "B30": "Why \"Group AB\" is correct:\n- Group AB blood has both A and B antigens present on erythrocyte surfaces (genotype IAIB), making recipients with AB phenotype compatible with blood from all ABO types but limiting donation opportunities. Group AB individuals possess neither anti-A nor anti-B antibodies naturally, allowing them to receive RBCs from groups A, B, AB, and O without agglutination reactions, earning them the designation as universal recipients. Approximately 3% of humans globally have AB blood type, the rarest ABO phenotype. However, group AB plasma should only be transfused to other AB recipients to avoid anti-A or anti-B reactions in recipients with those antibodies.\nWhy the other options are not correct:\n- \"Group O\" is incorrect because group O is the universal donor type for cells, not the universal recipient; group O recipients have anti-A and anti-B antibodies preventing O donation to other groups.\n- \"Group A\" is incorrect because group A recipients cannot receive B cells and group AB recipients cannot receive A plasma, limiting rather than enabling universal compatibility.\n- \"Group B\" is incorrect because group B recipients cannot receive A antigens, and group AB recipients cannot receive B plasma, not conferring universal recipient status."
})

print(f"Total explanations now: {len(explanations)}")
